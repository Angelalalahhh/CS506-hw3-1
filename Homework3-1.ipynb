# %% [markdown]
# # Scraping Hotel Ratings on Booking #

# %% [markdown]
# In this homework we will practice web scraping on the following [site](https://www.booking.com/searchresults.html?aid=304142&label=gen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmcgV1c19tYYgBAZgBMcIBA2FibsgBDdgBA-gBAfgBApICAXmoAgQ&sid=28d97f630803f9d48b4a1f535cbdd33f&class_interval=1&dest_id=20061717&dest_type=city&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A%2CA&sb_price_type=total&src=index&src_elem=sb&ss=Boston&ssb=empty&ssne_untouched=Cancún&rows=15). Let's get some basic information for each hotel in Boston.
# On each hotel page, scrape the following information:
# 1. Hotel Name
# 2. Class of Rating (Wonderful/Excellent/Very Good/Good)
# 3. Rating Score
# 4. Number of Reviews
#
#
# ** Save the data in "traveler_ratings.csv" in the following format: hotel_name, class_of_rating, rating, num_reviews **
#
# **(10 pts)**
#
# You can see an overview of the information as displayed:
#
#
#
#
#
# ![Information to be scraped](booking_sample.png)

# %% [markdown]
# Now let's scrape some reviews. For each review of each each hotel in Boston you are to scrape the following attributes:
# 1. Reviewer name
# 2. Reviewer ethnicity
# 3. Number of reviews
# 4. Number of helpful votes
# 5. Date
# 6. Rating
# 7. Negative Review
# 8. Positive Review
#
# Note that you will also need the hotel's name!! Also, some reviews may not have all attributes.
#
# ** Save the data in "review_ratings.csv" in the following format: hotel_name, reviewer_name, ethnicity, num_reviews, num_help_votes, date, rating, neg_review, pos_review **
#
# **(25 pts)**
#
# You can see an overview of the information as displayed:
# ![Information to be scraped](review_sample.png)

# %%
import requests
url = 'https://www.booking.com/searchresults.html?aid=304142&label=gen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmcgV1c19tYYgBAZgBMcIBA2FibsgBDdgBA-gBAfgBApICAXmoAgQ&sid=28d97f630803f9d48b4a1f535cbdd33f&class_interval=1&dest_id=20061717&dest_type=city&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A%2CA&sb_price_type=total&src=index&src_elem=sb&ss=Boston&ssb=empty&ssne_untouched=Canc%C3%BAn&rows=15'
response = requests.get(url)
html = response.text.encode('utf-8')

# %%
# the following code comes from Ms. Spinelli's python file with some modification
from bs4 import BeautifulSoup
import sys
import time
import os
import logging
import argparse
import codecs
import json
import re
def parse_hotellist_page(html):
    """ Parse the html pages returned by get_hotellist_page().
        Return the next url page to scrape (a city can have
        more than one page of hotels) if there is, else exit
        the script.
    """
    soup = BeautifulSoup(html, "html5lib")
    hotel_boxes = soup.findAll('div', {'class' :re.compile('sr_item_default')})
  
    for hotel_box in hotel_boxes:
               
        state = True
        try:
            name = hotel_box.find('span', {'class' :'sr-hotel__name'}).find(text=True).strip()
            name = name.replace(',', '')
        
        except Exception as e:
            state = False
            name = ""
            reviews = "N/A"
            ratings = "N/A"
            numreviews = "N/A"

        if (state):
            try:
                reviews = hotel_box.find('span', {'class' :'review-score-badge'}).find(text=True).strip()
            except Exception as e:
                reviews = "N/A"
            try:
                ratings = hotel_box.find('span', {'class' :'review-score-widget__text'}).find(text=True).strip()
            except Exception as e:
                ratings = "N/A"
            if ratings == '':
                try:
                    div = hotel_box.find('span', {'class' :'review-score-widget__text'})
                    parsestring = str(div).split('>')
                    ratings = parsestring[3].split('<')[0].strip()
                except Exception as e:
                    ratings = "N/A"
            try:
                numreviews = hotel_box.find('span', {'class' :'review-score-widget__subtext'}).find(text=True).strip()
                numreviews = ''.join(x for x in numreviews if x.isdigit())
            except Exception as e:
                numreviews = "N/A"
        print(name + ',' + ratings + ',' + reviews + ',' + numreviews, file = outfile)
            
    # Get next URL page if exists, else exit
    div = soup.find("div", {"class" : "results-paging"})

    # check if last page
    if div.find('span', {'class' : 'paging-end'}):
        return False
    # If it is not las page there must be the Next URL
    hrefs = div.findAll('a', href= True)

    for href in hrefs:
        if href.find(text = True) == 'Next page':
            url = href['href']
            response = requests.get(url)
            html = response.text.encode('utf-8')
            return parse_hotellist_page(html)

# %%
start = time.time()
outfile = open('traveler_ratings.csv', 'w')
print('hotel_name,class_of_rating,rating,num_reviews', file = outfile)
parse_hotellist_page(html)
outfile.close()
end = time.time()
print(end - start)
# Out:
# 140.69387817382812

# %%
# extract urls of all hotels in Boston and store them in a list
urls = []
def get_all_urls(html):
    soup = BeautifulSoup(html, "html5lib")
    hotel_boxes = soup.findAll('div', {'class' :re.compile('sr_item_default')})
  
    for hotel_box in hotel_boxes:  
        state = True
        try:
            name = hotel_box.find('span', {'class' :'sr-hotel__name'}).find(text=True).strip()
            name = name.replace(',', '')
        
        except Exception as e:
            state = False

        if (state):
            try:
                link = hotel_box.find('a', {'class' :'hotel_name_link url'})['href'].strip()
                url = 'https://www.booking.com' + link
                url = url[0:url.index('\n')]
                urls.append(url)
            except Exception as e:
                url = 'N/A'
            
    # Get next URL page if exists, else exit
    div = soup.find("div", {"class" : "results-paging"})

    # check if last page
    if div.find('span', {'class' : 'paging-end'}):
        return False
    # If it is not las page there must be the Next URL
    hrefs = div.findAll('a', href= True)

    for href in hrefs:
        if href.find(text = True) == 'Next page':
            url = href['href']
            response = requests.get(url)
            html = response.text.encode('utf-8')
            return get_all_urls(html)

# %%
url = 'https://www.booking.com/searchresults.html?aid=304142&label=gen173nr-1DCAEoggJCAlhYSDNiBW5vcmVmcgV1c19tYYgBAZgBMcIBA2FibsgBDdgBA-gBAfgBApICAXmoAgQ&sid=28d97f630803f9d48b4a1f535cbdd33f&class_interval=1&dest_id=20061717&dest_type=city&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A%2CA&sb_price_type=total&src=index&src_elem=sb&ss=Boston&ssb=empty&ssne_untouched=Canc%C3%BAn&rows=15'
response = requests.get(url)
html = response.text.encode('utf-8')
start = time.time()
get_all_urls(html)
end = time.time()
print(end - start)
# Out:
# 134.15015602111816

# %%
len(urls)
# Out:
# 398

# %%
urls
# Out:
# ['https://www.booking.com/hotel/us/oakwood-boston.html',
#  'https://www.booking.com/hotel/us/14-gloucester-st-2b-by-lyon-apartments-boston.html',
#  'https://www.booking.com/hotel/us/14-gloucester-st-4a-by-lyon-apartments.html',
#  'https://www.booking.com/hotel/us/112-myrtle-st-9.html',
#  'https://www.booking.com/hotel/us/two-bedroom-boston-luxury-apartment.html',
#  'https://www.booking.com/hotel/us/the-c-house-boston-massachusettes.html',
#  'https://www.booking.com/hotel/us/14-gloucester-st-2a-by-lyon-apartments-boston.html',
#  'https://www.booking.com/hotel/us/clearway-street-by-boston-furnished-rooms.html',
#  'https://www.booking.com/hotel/us/14-gloucester-st-unit-4b.html',
#  'https://www.booking.com/hotel/us/hyatt-harborside.html',
#  'https://www.booking.com/hotel/us/r-boston-massachusettes.html',
#  'https://www.booking.com/hotel/us/hyatt-regency-boston.html',
#  'https://www.booking.com/hotel/us/the-godfrey-boston.html',
#  'https://www.booking.com/hotel/us/super-location-2br-47-1bath-1-parking-spot.html',
#  'https://www.booking.com/hotel/us/315-on-a-by-stay-alfred.html',
#  'https://www.booking.com/hotel/us/c-boston-massachusettes.html',
#  'https://www.booking.com/hotel/us/renaissance-waterfront.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-washington-street-apt-207.html',
#  'https://www.booking.com/hotel/us/loews-boston-hotel.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-washington-street-apt-304.html',
#  'https://www.booking.com/hotel/us/yotel-boston.html',
#  'https://www.booking.com/hotel/us/140.html',
#  'https://www.booking.com/hotel/us/luxury-apartments-steps-away-from-china-town-and-theater-district.html',
#  'https://www.booking.com/hotel/us/garrison-square-by-stay-alfred.html',
#  'https://www.booking.com/hotel/us/660-washington-by-stay-alfred.html',
#  'https://www.booking.com/hotel/us/westin-copley-place.html',
#  'https://www.booking.com/hotel/us/apartment-on-milk-street-5b.html',
#  'https://www.booking.com/hotel/us/four-seasons-boston.html',
#  'https://www.booking.com/hotel/us/longfellow-by-stay-alfred.html',
#  'https://www.booking.com/hotel/us/seaport.html',
#  'https://www.booking.com/hotel/us/seaport.html',
#  'https://www.booking.com/hotel/us/112-myrtle-st-9.html',
#  'https://www.booking.com/hotel/us/d-street.html',
#  'https://www.booking.com/hotel/us/patrick-39-s-place.html',
#  'https://www.booking.com/hotel/us/sheraton-boston-towers.html',
#  'https://www.booking.com/hotel/us/newbury-guest-house.html',
#  'https://www.booking.com/hotel/us/two-bedroom-house-on-columbus-avenue.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-d-street-apt-344.html',
#  'https://www.booking.com/hotel/us/14-gloucester-st-unit-4b.html',
#  'https://www.booking.com/hotel/us/three-bedroom-on-hamilton-place-apt-305.html',
#  'https://www.booking.com/hotel/us/kenmore-apartments-by-starlight-suites.html',
#  'https://www.booking.com/hotel/us/14-gloucester-st-b-by-lyon-apartments.html',
#  'https://www.booking.com/hotel/us/112-myrtle-st-5.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-arch-street-5d.html',
#  'https://www.booking.com/hotel/us/apartment-backbay.html',
#  'https://www.booking.com/hotel/us/three-bedroom-on-hamilton-place-apt-408.html',
#  'https://www.booking.com/hotel/us/taj-boston.html',
#  'https://www.booking.com/hotel/us/102-chandler-9-by-lyon-apartments.html',
#  'https://www.booking.com/hotel/us/luxury-apartments-in-the-heart-of-fenway.html',
#  'https://www.booking.com/hotel/us/112-myrtle-st-1.html',
#  'https://www.booking.com/hotel/us/bluebird-suites-in-the-heart-of-fenway.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-washington-street-apt-204.html',
#  'https://www.booking.com/hotel/us/intercontinental-boston.html',
#  'https://www.booking.com/hotel/us/112-myrtle-st-7.html',
#  'https://www.booking.com/hotel/us/millennium-bostonian.html',
#  'https://www.booking.com/hotel/us/aloft-boston-seaport.html',
#  'https://www.booking.com/hotel/us/hyatt-harborside.html',
#  'https://www.booking.com/hotel/us/bluebird-suites-at-boston-39-s-theatre-district.html',
#  'https://www.booking.com/hotel/us/the-lenox.html',
#  'https://www.booking.com/hotel/us/ac-by-marriott-boston-downtown.html',
#  'https://www.booking.com/hotel/us/three-bedroom-on-hamilton-place-apt-508.html',
#  'https://www.booking.com/hotel/us/avenir-by-stay-alfred.html',
#  'https://www.booking.com/hotel/us/hilton-garden-inn-boston-logan-airport.html',
#  'https://www.booking.com/hotel/us/club-quarters-in-boston.html',
#  'https://www.booking.com/hotel/us/battery-wharf-hotel.html',
#  'https://www.booking.com/hotel/us/temple-place-suites-by-short-term-rentals-boston.html',
#  'https://www.booking.com/hotel/us/modern-spacious-two-bedroom-with-balcony.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-washington-street-apt-308.html',
#  'https://www.booking.com/hotel/us/chandler-inn.html',
#  'https://www.booking.com/hotel/us/three-bedroom-on-larose-place-apt-l.html',
#  'https://www.booking.com/hotel/us/global-serviced-apartments.html',
#  'https://www.booking.com/hotel/us/hilton-logan-airport.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-hamilton-place-apt-402.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-boylston-street-apt-9.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-columbia-road-apt-1d.html',
#  'https://www.booking.com/hotel/us/hilton-logan-airport.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-hamilton-place-apt-402.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-boylston-street-apt-9.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-columbia-road-apt-1d.html',
#  'https://www.booking.com/hotel/us/hotel-boston.html',
#  'https://www.booking.com/hotel/us/the-kensington.html',
#  'https://www.booking.com/hotel/us/bricco-suites.html',
#  'https://www.booking.com/hotel/us/the-baldwin-at-longwood-medical-area.html',
#  'https://www.booking.com/hotel/us/luxury-1-bedroom-apartment-near-td-garden.html',
#  'https://www.booking.com/hotel/us/w-boston.html',
#  'https://www.booking.com/hotel/us/milner-b-boston-massachusettes.html',
#  'https://www.booking.com/hotel/us/hyatt-regency-boston.html',
#  'https://www.booking.com/hotel/us/charlesmark.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-hamilton-place-apt-303.html',
#  'https://www.booking.com/hotel/us/studio-on-arch-street-4a.html',
#  'https://www.booking.com/hotel/us/three-bedroom-on-d-street-apt-20.html',
#  'https://www.booking.com/hotel/us/constitution-inn.html',
#  'https://www.booking.com/hotel/us/boston-harbor-view-luxury-suites.html',
#  'https://www.booking.com/hotel/us/boston-yacht-haven.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-hamilton-place-apt-501.html',
#  'https://www.booking.com/hotel/us/44-concord-square-boston-ma-back-bay-47-south-end.html',
#  'https://www.booking.com/hotel/us/boston-back-bay.html',
#  'https://www.booking.com/hotel/us/14-gloucester-st-unit-1b.html',
#  'https://www.booking.com/hotel/us/condo-on-western-avenue-404.html',
#  'https://www.booking.com/hotel/us/copley-garrison.html',
#  'https://www.booking.com/hotel/us/goodwin-beacon-hill-house.html',
#  'https://www.booking.com/hotel/us/studio-on-arch.html',
#  'https://www.booking.com/hotel/us/three-bedroom-apartment-on-brainerd-road-22.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-d-street-apt-350.html',
#  'https://www.booking.com/hotel/us/global-luxury-suites-on-olmstead-park.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-d-street-apt-350.html',
#  'https://www.booking.com/hotel/us/global-luxury-suites-on-olmstead-park.html',
#  'https://www.booking.com/hotel/us/copley-mariott.html',
#  'https://www.booking.com/hotel/us/studio-on-arch-street-4b.html',
#  'https://www.booking.com/hotel/us/charles-river-motel.html',
#  'https://www.booking.com/hotel/us/charming-apt-2br-47-1bath-1-private-parking-spot.html',
#  'https://www.booking.com/hotel/us/copley-square.html',
#  'https://www.booking.com/hotel/us/studio-on-arch-street-1a.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-e-springfield-street-apt-4.html',
#  'https://www.booking.com/hotel/us/boston-little-italy-two-bedrooms-h2d.html',
#  'https://www.booking.com/hotel/us/fenway-triangle-trilogy-boston.html',
#  'https://www.booking.com/hotel/us/apartment-in-historic-location.html',
#  'https://www.booking.com/hotel/us/beautiful-2br-47-1ba-in-convenient-north-end-location.html',
#  'https://www.booking.com/hotel/us/back-bay-beacon.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-arch-street-2c.html',
#  'https://www.booking.com/hotel/us/boston-harbor.html',
#  'https://www.booking.com/hotel/us/welcome-to-boston.html',
#  'https://www.booking.com/hotel/us/bw-roundhouse-suites.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-d-street-apt-353.html',
#  'https://www.booking.com/hotel/us/bluebird-suites-at-garrison-square.html',
#  'https://www.booking.com/hotel/us/westin-boston-waterfront.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-boylston-street-apt-914.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-hamilton-place-apt-401.html',
#  'https://www.booking.com/hotel/us/evolve-park-lane-seaport.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-brookline-avenue-apt-834.html',
#  'https://www.booking.com/hotel/us/the-eliot.html',
#  'https://www.booking.com/hotel/us/fairmont-copley-plaza.html',
#  'https://www.booking.com/hotel/us/gsa-luxury-apartments-at-1330-boylston-steet.html',
#  'https://www.booking.com/hotel/us/embassy-boston-logan.html',
#  'https://www.booking.com/hotel/us/studio-on-washington-street-apt-301.html',
#  'https://www.booking.com/hotel/us/boston-christopher.html',
#  'https://www.booking.com/hotel/us/nine-zero-hotel.html',
#  'https://www.booking.com/hotel/us/super-location-2br-47-1bath-1-parking-spot.html',
#  'https://www.booking.com/hotel/us/315-on-a-by-stay-alfred.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-d-street-apt-345.html',
#  'https://www.booking.com/hotel/us/inn-at-st-botolph.html',
#  'https://www.booking.com/hotel/us/the-envoy-autograph-collection.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-warrenton-street-apt-20.html',
#  'https://www.booking.com/hotel/us/gsa-luxury-apartment.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-d-street-apt-432.html',
#  'https://www.booking.com/hotel/us/boston-newbury.html',
#  'https://www.booking.com/hotel/us/jefferies-point-condos-by-airport-amp-subway-2.html',
#  'https://www.booking.com/hotel/us/c-boston-massachusettes.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-newbury-st-apt-41.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-warrenton-street-apt-5.html',
#  'https://www.booking.com/hotel/us/boston-park-plaza-boston.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-beacon-street-apt-17.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-d-street-apt-151.html',
#  'https://www.booking.com/hotel/us/c-i-boston-massachusettes.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-d-street-apt-136.html',
#  'https://www.booking.com/hotel/us/courtyard-boston-copley-square.html',
#  'https://www.booking.com/hotel/us/four-bedroom-on-hamilton-place-apt-406.html',
#  'https://www.booking.com/hotel/us/mandarin-oriental-boston.html',
#  'https://www.booking.com/hotel/us/garrison-luxury-furnished-suites.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-d-street-apt-312.html',
#  'https://www.booking.com/hotel/us/encore-b-b.html',
#  'https://www.booking.com/hotel/us/boston-omni-parker-house.html',
#  'https://www.booking.com/hotel/us/hampton-inn-crosstown-center.html',
#  'https://www.booking.com/hotel/us/the-liberty.html',
#  'https://www.booking.com/hotel/us/courtyard-boston-logan-airport.html',
#  'https://www.booking.com/hotel/us/luxury-apartments-in-boston-39-s-theatre-district.html',
#  'https://www.booking.com/hotel/us/102-chandler-st-1.html',
#  'https://www.booking.com/hotel/us/beech-glen-street-53.html',
#  'https://www.booking.com/hotel/us/evolve-suites-fenway.html',
#  'https://www.booking.com/hotel/us/courtyard-boston-south-boston.html',
#  'https://www.booking.com/hotel/us/historic-apartment-with-private-entry.html',
#  'https://www.booking.com/hotel/us/midtown.html',
#  'https://www.booking.com/hotel/us/102-chandler-4-by-lyon-apartments.html',
#  'https://www.booking.com/hotel/us/jefferies-point-condos-by-airport-amp-subway-3.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-washington-street-apt-206.html',
#  'https://www.booking.com/hotel/us/harrison-avenue-apartment.html',
#  'https://www.booking.com/hotel/us/the-west-end-family-getaway.html',
#  'https://www.booking.com/hotel/us/bluebird-suites-near-south-station.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-brookline-avenue-apt-634.html',
#  'https://www.booking.com/hotel/us/jefferies-point-condos-by-airport-amp-subway.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-washington-street-apt-407.html',
#  'https://www.booking.com/hotel/us/studio-on-washington-street-apt-202.html',
#  'https://www.booking.com/hotel/us/herbivorian-house.html',
#  'https://www.booking.com/hotel/us/element-boston-seaport.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-washington-street-apt-507.html',
#  'https://www.booking.com/hotel/us/three-bedroom-on-south-street-apt-11.html',
#  'https://www.booking.com/hotel/us/studio-on-washington-street-apt-203.html',
#  'https://www.booking.com/hotel/us/two-bedroom-apartment-on-arch-street-5c.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-commonwealth-avenue-apt-311.html',
#  'https://www.booking.com/hotel/us/tavares-rental.html',
#  'https://www.booking.com/hotel/us/three-bedroom-on-south-street-apt-5.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-elko-street-apt-8.html',
#  'https://www.booking.com/hotel/us/three-bedroom-on-hamilton-place-apt-405.html',
#  'https://www.booking.com/hotel/us/cherrywood-on-beacon-hill.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-hamilton-place-apt-302.html',
#  'https://www.booking.com/hotel/us/12-mt-vernon-street-by-short-term-rentals-boston.html',
#  'https://www.booking.com/hotel/us/apartment-on-milk-street-5a.html',
#  'https://www.booking.com/hotel/us/luxury-1-bed-apartment-in-the-heart-of-boston.html',
#  'https://www.booking.com/hotel/us/studio-apartments-on-newbury-street.html',
#  'https://www.booking.com/hotel/us/hilton-boston-fin-district.html',
#  'https://www.booking.com/hotel/us/studio-on-arch-street-3e.html',
#  'https://www.booking.com/hotel/us/best-boston-location-2br.html',
#  'https://www.booking.com/hotel/us/gorgeous-apt-by-bu-2br-47-1bath-private-parking.html',
#  'https://www.booking.com/hotel/us/hostelling-international-boston.html',
#  'https://www.booking.com/hotel/us/beautiful-2-bed-views-of-charles-river-back-bay.html',
#  'https://www.booking.com/hotel/us/spacious-modern-bedroom-brookline.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-western-avenue.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-brainerd-road-27.html',
#  'https://www.booking.com/hotel/us/apartments-on-washington-street.html',
#  'https://www.booking.com/hotel/us/studio-on-arch-street-3a.html',
#  'https://www.booking.com/hotel/us/apartments-on-washington-street.html',
#  'https://www.booking.com/hotel/us/studio-on-arch-street-3a.html',
#  'https://www.booking.com/hotel/us/one-bedroom-condo-on-western-avenue-s-418.html',
#  'https://www.booking.com/hotel/us/holiday-inn-express-boston.html',
#  'https://www.booking.com/hotel/us/oasis-guest-house.html',
#  'https://www.booking.com/hotel/us/studio-on-washington-street-apt-502.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-washington-street-apt-306.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-union-park-street-apt-2.html',
#  'https://www.booking.com/hotel/us/west-broadway-quarters.html',
#  'https://www.booking.com/hotel/us/apartment-on-tremont-street-402.html',
#  'https://www.booking.com/hotel/us/residence-inn-boston-back-bay-fenway.html',
#  'https://www.booking.com/hotel/us/evolve-in-east-boston.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-d-street-apt-106.html',
#  'https://www.booking.com/hotel/us/bluebird-suites-in-downtown-boston.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-boylston-street-apt-603.html',
#  'https://www.booking.com/hotel/us/best-boston-location-2br-m-4.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-beacon-street-206.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-hamilton-place-apt-301.html',
#  'https://www.booking.com/hotel/us/the-farrington-inn.html',
#  'https://www.booking.com/hotel/us/ames-boston.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-east-springfield-street-apt-b.html',
#  'https://www.booking.com/hotel/us/newbury-street-studio.html',
#  'https://www.booking.com/hotel/us/two-bedroom-apartment-in-china-town-near-tufts-by-stars-of-boston.html',
#  'https://www.booking.com/hotel/us/modern-brighton-getaway.html',
#  'https://www.booking.com/hotel/us/the-beacon-on-massachusetts-avenue-condo.html',
#  'https://www.booking.com/hotel/us/the-michelle-4.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-washington-street-apt-307.html',
#  'https://www.booking.com/hotel/us/apartment-by-tufts-medical-by-stars-of-boston.html',
#  'https://www.booking.com/hotel/us/best-western-boston-the-inn-at-longwood-medical.html',
#  'https://www.booking.com/hotel/us/apartment-on-warrenton-street-14.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-warrenton-street-19.html',
#  'https://www.booking.com/hotel/us/four-bedroom-on-hamilton-place-apt-407.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-d-street-apt-158.html',
#  'https://www.booking.com/hotel/us/the-michelle-3.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-hamilton-place-apt-503.html',
#  'https://www.booking.com/hotel/us/foursixtythree-beacon-street-guest-house.html',
#  'https://www.booking.com/hotel/us/penthouse-at-uphams-corner-condo.html',
#  'https://www.booking.com/hotel/us/two-bedroom-apartment-on-washington-street-402.html',
#  'https://www.booking.com/hotel/us/studio-on-arch-street-2b.html',
#  'https://www.booking.com/hotel/us/beacon-hill-apartment.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-arch-street-3d.html',
#  'https://www.booking.com/hotel/us/2-bedroom-apartment-in-downtown-boston.html',
#  'https://www.booking.com/hotel/us/kimpton-onyx-hotel.html',
#  'https://www.booking.com/hotel/us/two-bedroom-apartment-on-beacon-street-204.html',
#  'https://www.booking.com/hotel/us/studio-on-arch-street-2e.html',
#  'https://www.booking.com/hotel/us/apartment-on-milk-street-3f.html',
#  'https://www.booking.com/hotel/us/apartment-on-arch-street-2d.html',
#  'https://www.booking.com/hotel/us/renaissance-waterfront.html',
#  'https://www.booking.com/hotel/us/luxury-stay-boston-apartment-1.html',
#  'https://www.booking.com/hotel/us/studio-on-beacon-street-apt-14.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-d-street-apt-111.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-n-margin-street-apt-1.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-e-springfield-street-apt-3.html',
#  'https://www.booking.com/hotel/us/beacon-hill.html',
#  'https://www.booking.com/hotel/us/residence-inn-by-marriott-boston-downtown-seaport.html',
#  'https://www.booking.com/hotel/us/doubletree-club-bayside.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-newbury-street.html',
#  'https://www.booking.com/hotel/us/gorgeous-unique-3br-47-3ba-duplex-north-end-m-g.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-d-street-apt-323.html',
#  'https://www.booking.com/hotel/us/the-ritz-carlton-boston-commons.html',
#  'https://www.booking.com/hotel/us/the-michelle.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-d-street-apt-246.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-brookline-avenue-apt-203.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-d-street-apt-329-boston12.html',
#  'https://www.booking.com/hotel/us/boston-best-one-bedroom-duplex-h2c.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-arch-street-3c.html',
#  'https://www.booking.com/hotel/us/pier-4-boston.html',
#  'https://www.booking.com/hotel/us/boston-best-furnished-studio-h2a.html',
#  'https://www.booking.com/hotel/us/stunning-apt-bybu-2br-47-1full-bath-private-parking.html',
#  'https://www.booking.com/hotel/us/bright-south-end-1br-w-47-gym-pool.html',
#  'https://www.booking.com/hotel/us/four-bedroom-on-hamilton-place-apt-507.html',
#  'https://www.booking.com/hotel/us/marlborough-st-unit-1-furnished-back-bay-2-bed.html',
#  'https://www.booking.com/hotel/us/t-amp-e-realty.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-washington-street-205.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-chestnut-hill-avenue-apt-15.html',
#  'https://www.booking.com/hotel/us/charlesview-suites-back-bay.html',
#  'https://www.booking.com/hotel/us/226-newbury-street-apartment.html',
#  'https://www.booking.com/hotel/us/archstone-modernity.html',
#  'https://www.booking.com/hotel/us/two-bedroom-apartment-tremont-street.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-d-street-apt-348.html',
#  'https://www.booking.com/hotel/us/luxury-apartments-at-towers-at-longfellow.html',
#  'https://www.booking.com/hotel/us/new-modern-1br-near-t-in-brookline.html',
#  'https://www.booking.com/hotel/us/bluebird-suites-at-van-ness.html',
#  'https://www.booking.com/hotel/us/best-boston-location-2br-m-3.html',
#  'https://www.booking.com/hotel/us/back-bay-studio.html',
#  'https://www.booking.com/hotel/us/luxury-one-bedroom-apartment-near-boston-seaport.html',
#  'https://www.booking.com/hotel/us/two-bedroom-apartment-on-beacon-st208.html',
#  'https://www.booking.com/hotel/us/global-luxury-suites-at-boston-garden.html',
#  'https://www.booking.com/hotel/us/bulfinch.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-washington-street-apt-305.html',
#  'https://www.booking.com/hotel/us/boston-huge-1-br-best-location-h2b.html',
#  'https://www.booking.com/hotel/us/john-jeffries-house-boston.html',
#  'https://www.booking.com/hotel/us/quarters-on-dorchester-by-short-term-rentals-boston.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-boylston-street-11.html',
#  'https://www.booking.com/hotel/us/102-chandler-st.html',
#  'https://www.booking.com/hotel/us/bluebird-suites-at-boylston.html',
#  'https://www.booking.com/hotel/us/taylor-house-bed-and-breakfast.html',
#  'https://www.booking.com/hotel/us/two-bedroom-apartment-on-beacon-street-202.html',
#  'https://www.booking.com/hotel/us/chestnut-hill-studio-by-stars-of-boston.html',
#  'https://www.booking.com/hotel/us/west-end-hideaway.html',
#  'https://www.booking.com/hotel/us/egleston-square-condo-jamaica-plain.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-warrenton-street-3.html',
#  'https://www.booking.com/hotel/us/lofts-at-atlantic-wharf.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-brookline-avenue-apt-405.html',
#  'https://www.booking.com/hotel/us/allston-red-house-1-bed.html',
#  'https://www.booking.com/hotel/us/hamilton-crossing.html',
#  'https://www.booking.com/hotel/us/hotel-south-huntington-avenue-boston.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-hamilton-place-apt-403.html',
#  'https://www.booking.com/hotel/us/studio-on-arch-street-3b.html',
#  'https://www.booking.com/hotel/us/sky-view-on-jones-hill-condo.html',
#  'https://www.booking.com/hotel/us/two-bedroom-apartment-on-western-avenue-n301.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-warrenton-street-16.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-boylston-street.html',
#  'https://www.booking.com/hotel/us/two-bedroom-apartment-on-washington-street-403.html',
#  'https://www.booking.com/hotel/us/apartment-on-bay-state-road-3r.html',
#  'https://www.booking.com/hotel/us/bay-state-in-the-back-bay-condo.html',
#  'https://www.booking.com/hotel/us/global-luxury-suites-at-the-convention-center.html',
#  'https://www.booking.com/hotel/us/237-northampton-street-by-short-term-rentals-boston.html',
#  'https://www.booking.com/hotel/us/studio-on-arch-street-2a.html',
#  'https://www.booking.com/hotel/us/2-bedroom-house-in-brighton.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-arch-street-5a.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-arch-street-4c.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-warrenton-street-2.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-chestnut-hill-avenue-apt-19.html',
#  'https://www.booking.com/hotel/us/cool-place-in-front-the-subway-1-parking-spot.html',
#  'https://www.booking.com/hotel/us/studio-apartments-on-newbury-street-41.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-e-springfield-street-apt-2.html',
#  'https://www.booking.com/hotel/us/fifteen-beacon.html',
#  'https://www.booking.com/hotel/us/monument-square-home-on-bunker-hill-home.html',
#  'https://www.booking.com/hotel/us/sawyer-on-jones-hill-condo.html',
#  'https://www.booking.com/hotel/us/luxury-suite-in-bcec-seaport-by-lyx-boston.html',
#  'https://www.booking.com/hotel/us/the-michelle-2.html',
#  'https://www.booking.com/hotel/us/apartment-on-western-avenue-n322.html',
#  'https://www.booking.com/hotel/us/residence-inn-boston-harbor-on-tudor-wharf.html',
#  'https://www.booking.com/hotel/us/784-tremont-street-by-short-term-rentals-boston.html',
#  'https://www.booking.com/hotel/us/grand-view-on-jones-hill-condo.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-d-street-apt-234.html',
#  'https://www.booking.com/hotel/us/apartment-on-western-avenue-n314.html',
#  'https://www.booking.com/hotel/us/roseclair-at-uphams-corner-apts.html',
#  'https://www.booking.com/hotel/us/16-e-springfield-street-by-short-term-rentals-boston.html',
#  'https://www.booking.com/hotel/us/global-luxury-suites-at-mission-hill.html',
#  'https://www.booking.com/hotel/us/boston-marriott-long-wharf.html',
#  'https://www.booking.com/hotel/us/652-massachusetts-avenue-by-short-term-rentals-boston.html',
#  'https://www.booking.com/hotel/us/relax-n-quot-think-quot-about-next-business.html',
#  'https://www.booking.com/hotel/us/alameda-2-at-weld-farm-condo.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-beacon-st205.html',
#  'https://www.booking.com/hotel/us/holiday-inn-express-suites-boston.html',
#  'https://www.booking.com/hotel/us/apartment-on-washington-street-4.html',
#  'https://www.booking.com/hotel/us/two-bedroom-on-commonwealth-avenue-apt-1314.html',
#  'https://www.booking.com/hotel/us/moroccan-luxury-suites.html',
#  'https://www.booking.com/hotel/us/dorset-at-uphams-corner-condo.html',
#  'https://www.booking.com/hotel/us/birds-eye-view-boston.html',
#  'https://www.booking.com/hotel/us/the-longfellow-lookout.html',
#  'https://www.booking.com/hotel/us/royal-street-studio.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-boylston-street-8-boston.html',
#  'https://www.booking.com/hotel/us/shawmut-in-ashmont-village-condo.html',
#  'https://www.booking.com/hotel/us/affordable-studio-sleeps-6-one-free-parking-spot.html',
#  'https://www.booking.com/hotel/us/apartments-on-n-harvard-street-n308.html',
#  'https://www.booking.com/hotel/us/mayhew-at-uphams-corner-apts.html',
#  'https://www.booking.com/hotel/us/guild-street-townhouse.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-warrenton-street-18.html',
#  'https://www.booking.com/hotel/us/marriott-s-custom-house.html',
#  'https://www.booking.com/hotel/us/studio-on-arch-street-5b.html',
#  'https://www.booking.com/hotel/us/cozy-patio-pool-and-whole-foods.html',
#  'https://www.booking.com/hotel/us/oakwood-at-devonshire.html',
#  'https://www.booking.com/hotel/us/three-bedroom-apartment-on-western-avenue-s501.html',
#  'https://www.booking.com/hotel/us/pristine-brookline-1br-w-47-gym-near-t.html',
#  'https://www.booking.com/hotel/us/apartment-on-arch-street-4d.html',
#  'https://www.booking.com/hotel/us/apartment-on-western-avenue-n306.html',
#  'https://www.booking.com/hotel/us/zakims-view.html',
#  'https://www.booking.com/hotel/us/chandler-studios.html',
#  'https://www.booking.com/hotel/us/little-pearl.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-washington-street-5.html',
#  'https://www.booking.com/hotel/us/brighton-retreat-boston.html',
#  'https://www.booking.com/hotel/us/bluebird-suites-at-west-end.html',
#  'https://www.booking.com/hotel/us/watermark-seaport.html',
#  'https://www.booking.com/hotel/us/the-ledder-house-5.html',
#  'https://www.booking.com/hotel/us/234-newbury.html',
#  'https://www.booking.com/hotel/us/beautiful-bunker-hill-2-bd.html',
#  'https://www.booking.com/hotel/us/boston.html',
#  'https://www.booking.com/hotel/us/one-bedroom-apartment-on-arch-street-1b.html',
#  'https://www.booking.com/hotel/us/102-chandler-7-by-lyon-apartments-boston12.html',
#  'https://www.booking.com/hotel/us/102-chandler-5-by-lyon-apartments.html',
#  'https://www.booking.com/hotel/us/102-chandler-8-by-lyon-apartments.html',
#  'https://www.booking.com/hotel/us/102-chandler-6-by-lyon-apartments.html',
#  'https://www.booking.com/hotel/us/three-bedroom-on-south-street-apt-3.html',
#  'https://www.booking.com/hotel/us/one-bedroom-on-chestnut-hill-avenue-apt-9.html',
#  'https://www.booking.com/hotel/us/north-end-enchanted-cottage.html']

# %%
# get all valid and invalid urls for review pages
review_urls = []
def get_urls_for_reviews(urls):
    for url in urls:
        new = 'https://www.booking.com/reviews/us/hotel' + url[url.find('us')+2:]
        review_urls.append(new)

# %%
get_urls_for_reviews(urls)

# %%
review_urls
# Out:
# ['https://www.booking.com/reviews/us/hotel/oakwood-boston.html',
#  'https://www.booking.com/reviews/us/hotel/14-gloucester-st-2b-by-lyon-apartments-boston.html',
#  'https://www.booking.com/reviews/us/hotel/14-gloucester-st-4a-by-lyon-apartments.html',
#  'https://www.booking.com/reviews/us/hotel/112-myrtle-st-9.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-boston-luxury-apartment.html',
#  'https://www.booking.com/reviews/us/hotel/the-c-house-boston-massachusettes.html',
#  'https://www.booking.com/reviews/us/hotel/14-gloucester-st-2a-by-lyon-apartments-boston.html',
#  'https://www.booking.com/reviews/us/hotel/clearway-street-by-boston-furnished-rooms.html',
#  'https://www.booking.com/reviews/us/hotel/14-gloucester-st-unit-4b.html',
#  'https://www.booking.com/reviews/us/hotel/hyatt-harborside.html',
#  'https://www.booking.com/reviews/us/hotel/r-boston-massachusettes.html',
#  'https://www.booking.com/reviews/us/hotel/hyatt-regency-boston.html',
#  'https://www.booking.com/reviews/us/hotel/the-godfrey-boston.html',
#  'https://www.booking.com/reviews/us/hotel/super-location-2br-47-1bath-1-parking-spot.html',
#  'https://www.booking.com/reviews/us/hotel/315-on-a-by-stay-alfred.html',
#  'https://www.booking.com/reviews/us/hotel/c-boston-massachusettes.html',
#  'https://www.booking.com/reviews/us/hotel/renaissance-waterfront.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-washington-street-apt-207.html',
#  'https://www.booking.com/reviews/us/hotel/loews-boston-hotel.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-washington-street-apt-304.html',
#  'https://www.booking.com/reviews/us/hotel/yotel-boston.html',
#  'https://www.booking.com/reviews/us/hotel/140.html',
#  'https://www.booking.com/reviews/us/hotel/luxury-apartments-steps-away-from-china-town-and-theater-district.html',
#  'https://www.booking.com/reviews/us/hotel/garrison-square-by-stay-alfred.html',
#  'https://www.booking.com/reviews/us/hotel/660-washington-by-stay-alfred.html',
#  'https://www.booking.com/reviews/us/hotel/westin-copley-place.html',
#  'https://www.booking.com/reviews/us/hotel/apartment-on-milk-street-5b.html',
#  'https://www.booking.com/reviews/us/hotel/four-seasons-boston.html',
#  'https://www.booking.com/reviews/us/hotel/longfellow-by-stay-alfred.html',
#  'https://www.booking.com/reviews/us/hotel/seaport.html',
#  'https://www.booking.com/reviews/us/hotel/seaport.html',
#  'https://www.booking.com/reviews/us/hotel/112-myrtle-st-9.html',
#  'https://www.booking.com/reviews/us/hotel/d-street.html',
#  'https://www.booking.com/reviews/us/hotel/patrick-39-s-place.html',
#  'https://www.booking.com/reviews/us/hotel/sheraton-boston-towers.html',
#  'https://www.booking.com/reviews/us/hotel/newbury-guest-house.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-house-on-columbus-avenue.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-d-street-apt-344.html',
#  'https://www.booking.com/reviews/us/hotel/14-gloucester-st-unit-4b.html',
#  'https://www.booking.com/reviews/us/hotel/three-bedroom-on-hamilton-place-apt-305.html',
#  'https://www.booking.com/reviews/us/hotel/kenmore-apartments-by-starlight-suites.html',
#  'https://www.booking.com/reviews/us/hotel/14-gloucester-st-b-by-lyon-apartments.html',
#  'https://www.booking.com/reviews/us/hotel/112-myrtle-st-5.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-arch-street-5d.html',
#  'https://www.booking.com/reviews/us/hotel/apartment-backbay.html',
#  'https://www.booking.com/reviews/us/hotel/three-bedroom-on-hamilton-place-apt-408.html',
#  'https://www.booking.com/reviews/us/hotel/taj-boston.html',
#  'https://www.booking.com/reviews/us/hotel/102-chandler-9-by-lyon-apartments.html',
#  'https://www.booking.com/reviews/us/hotel/luxury-apartments-in-the-heart-of-fenway.html',
#  'https://www.booking.com/reviews/us/hotel/112-myrtle-st-1.html',
#  'https://www.booking.com/reviews/us/hotel/bluebird-suites-in-the-heart-of-fenway.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-washington-street-apt-204.html',
#  'https://www.booking.com/reviews/us/hotel/intercontinental-boston.html',
#  'https://www.booking.com/reviews/us/hotel/112-myrtle-st-7.html',
#  'https://www.booking.com/reviews/us/hotel/millennium-bostonian.html',
#  'https://www.booking.com/reviews/us/hotel/aloft-boston-seaport.html',
#  'https://www.booking.com/reviews/us/hotel/hyatt-harborside.html',
#  'https://www.booking.com/reviews/us/hotel/bluebird-suites-at-boston-39-s-theatre-district.html',
#  'https://www.booking.com/reviews/us/hotel/the-lenox.html',
#  'https://www.booking.com/reviews/us/hotel/ac-by-marriott-boston-downtown.html',
#  'https://www.booking.com/reviews/us/hotel/three-bedroom-on-hamilton-place-apt-508.html',
#  'https://www.booking.com/reviews/us/hotel/avenir-by-stay-alfred.html',
#  'https://www.booking.com/reviews/us/hotel/hilton-garden-inn-boston-logan-airport.html',
#  'https://www.booking.com/reviews/us/hotel/club-quarters-in-boston.html',
#  'https://www.booking.com/reviews/us/hotel/battery-wharf-hotel.html',
#  'https://www.booking.com/reviews/us/hotel/temple-place-suites-by-short-term-rentals-boston.html',
#  'https://www.booking.com/reviews/us/hotel/modern-spacious-two-bedroom-with-balcony.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-washington-street-apt-308.html',
#  'https://www.booking.com/reviews/us/hotel/chandler-inn.html',
#  'https://www.booking.com/reviews/us/hotel/three-bedroom-on-larose-place-apt-l.html',
#  'https://www.booking.com/reviews/us/hotel/global-serviced-apartments.html',
#  'https://www.booking.com/reviews/us/hotel/hilton-logan-airport.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-hamilton-place-apt-402.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-boylston-street-apt-9.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-columbia-road-apt-1d.html',
#  'https://www.booking.com/reviews/us/hotel/hilton-logan-airport.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-hamilton-place-apt-402.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-boylston-street-apt-9.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-columbia-road-apt-1d.html',
#  'https://www.booking.com/reviews/us/hotel/hotel-boston.html',
#  'https://www.booking.com/reviews/us/hotel/the-kensington.html',
#  'https://www.booking.com/reviews/us/hotel/bricco-suites.html',
#  'https://www.booking.com/reviews/us/hotel/the-baldwin-at-longwood-medical-area.html',
#  'https://www.booking.com/reviews/us/hotel/luxury-1-bedroom-apartment-near-td-garden.html',
#  'https://www.booking.com/reviews/us/hotel/w-boston.html',
#  'https://www.booking.com/reviews/us/hotel/milner-b-boston-massachusettes.html',
#  'https://www.booking.com/reviews/us/hotel/hyatt-regency-boston.html',
#  'https://www.booking.com/reviews/us/hotel/charlesmark.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-hamilton-place-apt-303.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-arch-street-4a.html',
#  'https://www.booking.com/reviews/us/hotel/three-bedroom-on-d-street-apt-20.html',
#  'https://www.booking.com/reviews/us/hotel/constitution-inn.html',
#  'https://www.booking.com/reviews/us/hotel/boston-harbor-view-luxury-suites.html',
#  'https://www.booking.com/reviews/us/hotel/boston-yacht-haven.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-hamilton-place-apt-501.html',
#  'https://www.booking.com/reviews/us/hotel/44-concord-square-boston-ma-back-bay-47-south-end.html',
#  'https://www.booking.com/reviews/us/hotel/boston-back-bay.html',
#  'https://www.booking.com/reviews/us/hotel/14-gloucester-st-unit-1b.html',
#  'https://www.booking.com/reviews/us/hotel/condo-on-western-avenue-404.html',
#  'https://www.booking.com/reviews/us/hotel/copley-garrison.html',
#  'https://www.booking.com/reviews/us/hotel/goodwin-beacon-hill-house.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-arch.html',
#  'https://www.booking.com/reviews/us/hotel/three-bedroom-apartment-on-brainerd-road-22.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-d-street-apt-350.html',
#  'https://www.booking.com/reviews/us/hotel/global-luxury-suites-on-olmstead-park.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-d-street-apt-350.html',
#  'https://www.booking.com/reviews/us/hotel/global-luxury-suites-on-olmstead-park.html',
#  'https://www.booking.com/reviews/us/hotel/copley-mariott.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-arch-street-4b.html',
#  'https://www.booking.com/reviews/us/hotel/charles-river-motel.html',
#  'https://www.booking.com/reviews/us/hotel/charming-apt-2br-47-1bath-1-private-parking-spot.html',
#  'https://www.booking.com/reviews/us/hotel/copley-square.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-arch-street-1a.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-e-springfield-street-apt-4.html',
#  'https://www.booking.com/reviews/us/hotel/boston-little-italy-two-bedrooms-h2d.html',
#  'https://www.booking.com/reviews/us/hotel/fenway-triangle-trilogy-boston.html',
#  'https://www.booking.com/reviews/us/hotel/apartment-in-historic-location.html',
#  'https://www.booking.com/reviews/us/hotel/beautiful-2br-47-1ba-in-convenient-north-end-location.html',
#  'https://www.booking.com/reviews/us/hotel/back-bay-beacon.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-arch-street-2c.html',
#  'https://www.booking.com/reviews/us/hotel/boston-harbor.html',
#  'https://www.booking.com/reviews/us/hotel/welcome-to-boston.html',
#  'https://www.booking.com/reviews/us/hotel/bw-roundhouse-suites.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-d-street-apt-353.html',
#  'https://www.booking.com/reviews/us/hotel/bluebird-suites-at-garrison-square.html',
#  'https://www.booking.com/reviews/us/hotel/westin-boston-waterfront.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-boylston-street-apt-914.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-hamilton-place-apt-401.html',
#  'https://www.booking.com/reviews/us/hotel/evolve-park-lane-seaport.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-brookline-avenue-apt-834.html',
#  'https://www.booking.com/reviews/us/hotel/the-eliot.html',
#  'https://www.booking.com/reviews/us/hotel/fairmont-copley-plaza.html',
#  'https://www.booking.com/reviews/us/hotel/gsa-luxury-apartments-at-1330-boylston-steet.html',
#  'https://www.booking.com/reviews/us/hotel/embassy-boston-logan.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-washington-street-apt-301.html',
#  'https://www.booking.com/reviews/us/hotel/boston-christopher.html',
#  'https://www.booking.com/reviews/us/hotel/nine-zero-hotel.html',
#  'https://www.booking.com/reviews/us/hotel/super-location-2br-47-1bath-1-parking-spot.html',
#  'https://www.booking.com/reviews/us/hotel/315-on-a-by-stay-alfred.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-d-street-apt-345.html',
#  'https://www.booking.com/reviews/us/hotel/inn-at-st-botolph.html',
#  'https://www.booking.com/reviews/us/hotel/the-envoy-autograph-collection.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-warrenton-street-apt-20.html',
#  'https://www.booking.com/reviews/us/hotel/gsa-luxury-apartment.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-d-street-apt-432.html',
#  'https://www.booking.com/reviews/us/hotel/boston-newbury.html',
#  'https://www.booking.com/reviews/us/hotel/jefferies-point-condos-by-airport-amp-subway-2.html',
#  'https://www.booking.com/reviews/us/hotel/c-boston-massachusettes.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-newbury-st-apt-41.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-warrenton-street-apt-5.html',
#  'https://www.booking.com/reviews/us/hotel/boston-park-plaza-boston.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-beacon-street-apt-17.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-d-street-apt-151.html',
#  'https://www.booking.com/reviews/us/hotel/c-i-boston-massachusettes.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-d-street-apt-136.html',
#  'https://www.booking.com/reviews/us/hotel/courtyard-boston-copley-square.html',
#  'https://www.booking.com/reviews/us/hotel/four-bedroom-on-hamilton-place-apt-406.html',
#  'https://www.booking.com/reviews/us/hotel/mandarin-oriental-boston.html',
#  'https://www.booking.com/reviews/us/hotel/garrison-luxury-furnished-suites.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-d-street-apt-312.html',
#  'https://www.booking.com/reviews/us/hotel/encore-b-b.html',
#  'https://www.booking.com/reviews/us/hotel/boston-omni-parker-house.html',
#  'https://www.booking.com/reviews/us/hotel/hampton-inn-crosstown-center.html',
#  'https://www.booking.com/reviews/us/hotel/the-liberty.html',
#  'https://www.booking.com/reviews/us/hotel/courtyard-boston-logan-airport.html',
#  'https://www.booking.com/reviews/us/hotel/luxury-apartments-in-boston-39-s-theatre-district.html',
#  'https://www.booking.com/reviews/us/hotel/102-chandler-st-1.html',
#  'https://www.booking.com/reviews/us/hotel/beech-glen-street-53.html',
#  'https://www.booking.com/reviews/us/hotel/evolve-suites-fenway.html',
#  'https://www.booking.com/reviews/us/hotel/courtyard-boston-south-boston.html',
#  'https://www.booking.com/reviews/us/hotel/historic-apartment-with-private-entry.html',
#  'https://www.booking.com/reviews/us/hotel/midtown.html',
#  'https://www.booking.com/reviews/us/hotel/102-chandler-4-by-lyon-apartments.html',
#  'https://www.booking.com/reviews/us/hotel/jefferies-point-condos-by-airport-amp-subway-3.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-washington-street-apt-206.html',
#  'https://www.booking.com/reviews/us/hotel/harrison-avenue-apartment.html',
#  'https://www.booking.com/reviews/us/hotel/the-west-end-family-getaway.html',
#  'https://www.booking.com/reviews/us/hotel/bluebird-suites-near-south-station.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-brookline-avenue-apt-634.html',
#  'https://www.booking.com/reviews/us/hotel/jefferies-point-condos-by-airport-amp-subway.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-washington-street-apt-407.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-washington-street-apt-202.html',
#  'https://www.booking.com/reviews/us/hotel/herbivorian-house.html',
#  'https://www.booking.com/reviews/us/hotel/element-boston-seaport.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-washington-street-apt-507.html',
#  'https://www.booking.com/reviews/us/hotel/three-bedroom-on-south-street-apt-11.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-washington-street-apt-203.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-apartment-on-arch-street-5c.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-commonwealth-avenue-apt-311.html',
#  'https://www.booking.com/reviews/us/hotel/tavares-rental.html',
#  'https://www.booking.com/reviews/us/hotel/three-bedroom-on-south-street-apt-5.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-elko-street-apt-8.html',
#  'https://www.booking.com/reviews/us/hotel/three-bedroom-on-hamilton-place-apt-405.html',
#  'https://www.booking.com/reviews/us/hotel/cherrywood-on-beacon-hill.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-hamilton-place-apt-302.html',
#  'https://www.booking.com/reviews/us/hotel/12-mt-vernon-street-by-short-term-rentals-boston.html',
#  'https://www.booking.com/reviews/us/hotel/apartment-on-milk-street-5a.html',
#  'https://www.booking.com/reviews/us/hotel/luxury-1-bed-apartment-in-the-heart-of-boston.html',
#  'https://www.booking.com/reviews/us/hotel/studio-apartments-on-newbury-street.html',
#  'https://www.booking.com/reviews/us/hotel/hilton-boston-fin-district.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-arch-street-3e.html',
#  'https://www.booking.com/reviews/us/hotel/best-boston-location-2br.html',
#  'https://www.booking.com/reviews/us/hotel/gorgeous-apt-by-bu-2br-47-1bath-private-parking.html',
#  'https://www.booking.com/reviews/us/hotel/hostelling-international-boston.html',
#  'https://www.booking.com/reviews/us/hotel/beautiful-2-bed-views-of-charles-river-back-bay.html',
#  'https://www.booking.com/reviews/us/hotel/spacious-modern-bedroom-brookline.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-western-avenue.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-brainerd-road-27.html',
#  'https://www.booking.com/reviews/us/hotel/apartments-on-washington-street.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-arch-street-3a.html',
#  'https://www.booking.com/reviews/us/hotel/apartments-on-washington-street.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-arch-street-3a.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-condo-on-western-avenue-s-418.html',
#  'https://www.booking.com/reviews/us/hotel/holiday-inn-express-boston.html',
#  'https://www.booking.com/reviews/us/hotel/oasis-guest-house.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-washington-street-apt-502.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-washington-street-apt-306.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-union-park-street-apt-2.html',
#  'https://www.booking.com/reviews/us/hotel/west-broadway-quarters.html',
#  'https://www.booking.com/reviews/us/hotel/apartment-on-tremont-street-402.html',
#  'https://www.booking.com/reviews/us/hotel/residence-inn-boston-back-bay-fenway.html',
#  'https://www.booking.com/reviews/us/hotel/evolve-in-east-boston.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-d-street-apt-106.html',
#  'https://www.booking.com/reviews/us/hotel/bluebird-suites-in-downtown-boston.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-boylston-street-apt-603.html',
#  'https://www.booking.com/reviews/us/hotel/best-boston-location-2br-m-4.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-beacon-street-206.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-hamilton-place-apt-301.html',
#  'https://www.booking.com/reviews/us/hotel/the-farrington-inn.html',
#  'https://www.booking.com/reviews/us/hotel/ames-boston.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-east-springfield-street-apt-b.html',
#  'https://www.booking.com/reviews/us/hotel/newbury-street-studio.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-apartment-in-china-town-near-tufts-by-stars-of-boston.html',
#  'https://www.booking.com/reviews/us/hotel/modern-brighton-getaway.html',
#  'https://www.booking.com/reviews/us/hotel/the-beacon-on-massachusetts-avenue-condo.html',
#  'https://www.booking.com/reviews/us/hotel/the-michelle-4.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-washington-street-apt-307.html',
#  'https://www.booking.com/reviews/us/hotel/apartment-by-tufts-medical-by-stars-of-boston.html',
#  'https://www.booking.com/reviews/us/hotel/best-western-boston-the-inn-at-longwood-medical.html',
#  'https://www.booking.com/reviews/us/hotel/apartment-on-warrenton-street-14.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-warrenton-street-19.html',
#  'https://www.booking.com/reviews/us/hotel/four-bedroom-on-hamilton-place-apt-407.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-d-street-apt-158.html',
#  'https://www.booking.com/reviews/us/hotel/the-michelle-3.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-hamilton-place-apt-503.html',
#  'https://www.booking.com/reviews/us/hotel/foursixtythree-beacon-street-guest-house.html',
#  'https://www.booking.com/reviews/us/hotel/penthouse-at-uphams-corner-condo.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-apartment-on-washington-street-402.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-arch-street-2b.html',
#  'https://www.booking.com/reviews/us/hotel/beacon-hill-apartment.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-arch-street-3d.html',
#  'https://www.booking.com/reviews/us/hotel/2-bedroom-apartment-in-downtown-boston.html',
#  'https://www.booking.com/reviews/us/hotel/kimpton-onyx-hotel.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-apartment-on-beacon-street-204.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-arch-street-2e.html',
#  'https://www.booking.com/reviews/us/hotel/apartment-on-milk-street-3f.html',
#  'https://www.booking.com/reviews/us/hotel/apartment-on-arch-street-2d.html',
#  'https://www.booking.com/reviews/us/hotel/renaissance-waterfront.html',
#  'https://www.booking.com/reviews/us/hotel/luxury-stay-boston-apartment-1.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-beacon-street-apt-14.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-d-street-apt-111.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-n-margin-street-apt-1.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-e-springfield-street-apt-3.html',
#  'https://www.booking.com/reviews/us/hotel/beacon-hill.html',
#  'https://www.booking.com/reviews/us/hotel/residence-inn-by-marriott-boston-downtown-seaport.html',
#  'https://www.booking.com/reviews/us/hotel/doubletree-club-bayside.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-newbury-street.html',
#  'https://www.booking.com/reviews/us/hotel/gorgeous-unique-3br-47-3ba-duplex-north-end-m-g.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-d-street-apt-323.html',
#  'https://www.booking.com/reviews/us/hotel/the-ritz-carlton-boston-commons.html',
#  'https://www.booking.com/reviews/us/hotel/the-michelle.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-d-street-apt-246.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-brookline-avenue-apt-203.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-d-street-apt-329-boston12.html',
#  'https://www.booking.com/reviews/us/hotel/boston-best-one-bedroom-duplex-h2c.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-arch-street-3c.html',
#  'https://www.booking.com/reviews/us/hotel/pier-4-boston.html',
#  'https://www.booking.com/reviews/us/hotel/boston-best-furnished-studio-h2a.html',
#  'https://www.booking.com/reviews/us/hotel/stunning-apt-bybu-2br-47-1full-bath-private-parking.html',
#  'https://www.booking.com/reviews/us/hotel/bright-south-end-1br-w-47-gym-pool.html',
#  'https://www.booking.com/reviews/us/hotel/four-bedroom-on-hamilton-place-apt-507.html',
#  'https://www.booking.com/reviews/us/hotel/marlborough-st-unit-1-furnished-back-bay-2-bed.html',
#  'https://www.booking.com/reviews/us/hotel/t-amp-e-realty.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-washington-street-205.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-chestnut-hill-avenue-apt-15.html',
#  'https://www.booking.com/reviews/us/hotel/charlesview-suites-back-bay.html',
#  'https://www.booking.com/reviews/us/hotel/226-newbury-street-apartment.html',
#  'https://www.booking.com/reviews/us/hotel/archstone-modernity.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-apartment-tremont-street.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-d-street-apt-348.html',
#  'https://www.booking.com/reviews/us/hotel/luxury-apartments-at-towers-at-longfellow.html',
#  'https://www.booking.com/reviews/us/hotel/new-modern-1br-near-t-in-brookline.html',
#  'https://www.booking.com/reviews/us/hotel/bluebird-suites-at-van-ness.html',
#  'https://www.booking.com/reviews/us/hotel/best-boston-location-2br-m-3.html',
#  'https://www.booking.com/reviews/us/hotel/back-bay-studio.html',
#  'https://www.booking.com/reviews/us/hotel/luxury-one-bedroom-apartment-near-boston-seaport.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-apartment-on-beacon-st208.html',
#  'https://www.booking.com/reviews/us/hotel/global-luxury-suites-at-boston-garden.html',
#  'https://www.booking.com/reviews/us/hotel/bulfinch.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-washington-street-apt-305.html',
#  'https://www.booking.com/reviews/us/hotel/boston-huge-1-br-best-location-h2b.html',
#  'https://www.booking.com/reviews/us/hotel/john-jeffries-house-boston.html',
#  'https://www.booking.com/reviews/us/hotel/quarters-on-dorchester-by-short-term-rentals-boston.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-boylston-street-11.html',
#  'https://www.booking.com/reviews/us/hotel/102-chandler-st.html',
#  'https://www.booking.com/reviews/us/hotel/bluebird-suites-at-boylston.html',
#  'https://www.booking.com/reviews/us/hotel/taylor-house-bed-and-breakfast.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-apartment-on-beacon-street-202.html',
#  'https://www.booking.com/reviews/us/hotel/chestnut-hill-studio-by-stars-of-boston.html',
#  'https://www.booking.com/reviews/us/hotel/west-end-hideaway.html',
#  'https://www.booking.com/reviews/us/hotel/egleston-square-condo-jamaica-plain.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-warrenton-street-3.html',
#  'https://www.booking.com/reviews/us/hotel/lofts-at-atlantic-wharf.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-brookline-avenue-apt-405.html',
#  'https://www.booking.com/reviews/us/hotel/allston-red-house-1-bed.html',
#  'https://www.booking.com/reviews/us/hotel/hamilton-crossing.html',
#  'https://www.booking.com/reviews/us/hotel/hotel-south-huntington-avenue-boston.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-hamilton-place-apt-403.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-arch-street-3b.html',
#  'https://www.booking.com/reviews/us/hotel/sky-view-on-jones-hill-condo.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-apartment-on-western-avenue-n301.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-warrenton-street-16.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-boylston-street.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-apartment-on-washington-street-403.html',
#  'https://www.booking.com/reviews/us/hotel/apartment-on-bay-state-road-3r.html',
#  'https://www.booking.com/reviews/us/hotel/bay-state-in-the-back-bay-condo.html',
#  'https://www.booking.com/reviews/us/hotel/global-luxury-suites-at-the-convention-center.html',
#  'https://www.booking.com/reviews/us/hotel/237-northampton-street-by-short-term-rentals-boston.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-arch-street-2a.html',
#  'https://www.booking.com/reviews/us/hotel/2-bedroom-house-in-brighton.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-arch-street-5a.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-arch-street-4c.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-warrenton-street-2.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-chestnut-hill-avenue-apt-19.html',
#  'https://www.booking.com/reviews/us/hotel/cool-place-in-front-the-subway-1-parking-spot.html',
#  'https://www.booking.com/reviews/us/hotel/studio-apartments-on-newbury-street-41.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-e-springfield-street-apt-2.html',
#  'https://www.booking.com/reviews/us/hotel/fifteen-beacon.html',
#  'https://www.booking.com/reviews/us/hotel/monument-square-home-on-bunker-hill-home.html',
#  'https://www.booking.com/reviews/us/hotel/sawyer-on-jones-hill-condo.html',
#  'https://www.booking.com/reviews/us/hotel/luxury-suite-in-bcec-seaport-by-lyx-boston.html',
#  'https://www.booking.com/reviews/us/hotel/the-michelle-2.html',
#  'https://www.booking.com/reviews/us/hotel/apartment-on-western-avenue-n322.html',
#  'https://www.booking.com/reviews/us/hotel/residence-inn-boston-harbor-on-tudor-wharf.html',
#  'https://www.booking.com/reviews/us/hotel/784-tremont-street-by-short-term-rentals-boston.html',
#  'https://www.booking.com/reviews/us/hotel/grand-view-on-jones-hill-condo.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-d-street-apt-234.html',
#  'https://www.booking.com/reviews/us/hotel/apartment-on-western-avenue-n314.html',
#  'https://www.booking.com/reviews/us/hotel/roseclair-at-uphams-corner-apts.html',
#  'https://www.booking.com/reviews/us/hotel/16-e-springfield-street-by-short-term-rentals-boston.html',
#  'https://www.booking.com/reviews/us/hotel/global-luxury-suites-at-mission-hill.html',
#  'https://www.booking.com/reviews/us/hotel/boston-marriott-long-wharf.html',
#  'https://www.booking.com/reviews/us/hotel/652-massachusetts-avenue-by-short-term-rentals-boston.html',
#  'https://www.booking.com/reviews/us/hotel/relax-n-quot-think-quot-about-next-business.html',
#  'https://www.booking.com/reviews/us/hotel/alameda-2-at-weld-farm-condo.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-beacon-st205.html',
#  'https://www.booking.com/reviews/us/hotel/holiday-inn-express-suites-boston.html',
#  'https://www.booking.com/reviews/us/hotel/apartment-on-washington-street-4.html',
#  'https://www.booking.com/reviews/us/hotel/two-bedroom-on-commonwealth-avenue-apt-1314.html',
#  'https://www.booking.com/reviews/us/hotel/moroccan-luxury-suites.html',
#  'https://www.booking.com/reviews/us/hotel/dorset-at-uphams-corner-condo.html',
#  'https://www.booking.com/reviews/us/hotel/birds-eye-view-boston.html',
#  'https://www.booking.com/reviews/us/hotel/the-longfellow-lookout.html',
#  'https://www.booking.com/reviews/us/hotel/royal-street-studio.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-boylston-street-8-boston.html',
#  'https://www.booking.com/reviews/us/hotel/shawmut-in-ashmont-village-condo.html',
#  'https://www.booking.com/reviews/us/hotel/affordable-studio-sleeps-6-one-free-parking-spot.html',
#  'https://www.booking.com/reviews/us/hotel/apartments-on-n-harvard-street-n308.html',
#  'https://www.booking.com/reviews/us/hotel/mayhew-at-uphams-corner-apts.html',
#  'https://www.booking.com/reviews/us/hotel/guild-street-townhouse.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-warrenton-street-18.html',
#  'https://www.booking.com/reviews/us/hotel/marriott-s-custom-house.html',
#  'https://www.booking.com/reviews/us/hotel/studio-on-arch-street-5b.html',
#  'https://www.booking.com/reviews/us/hotel/cozy-patio-pool-and-whole-foods.html',
#  'https://www.booking.com/reviews/us/hotel/oakwood-at-devonshire.html',
#  'https://www.booking.com/reviews/us/hotel/three-bedroom-apartment-on-western-avenue-s501.html',
#  'https://www.booking.com/reviews/us/hotel/pristine-brookline-1br-w-47-gym-near-t.html',
#  'https://www.booking.com/reviews/us/hotel/apartment-on-arch-street-4d.html',
#  'https://www.booking.com/reviews/us/hotel/apartment-on-western-avenue-n306.html',
#  'https://www.booking.com/reviews/us/hotel/zakims-view.html',
#  'https://www.booking.com/reviews/us/hotel/chandler-studios.html',
#  'https://www.booking.com/reviews/us/hotel/little-pearl.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-washington-street-5.html',
#  'https://www.booking.com/reviews/us/hotel/brighton-retreat-boston.html',
#  'https://www.booking.com/reviews/us/hotel/bluebird-suites-at-west-end.html',
#  'https://www.booking.com/reviews/us/hotel/watermark-seaport.html',
#  'https://www.booking.com/reviews/us/hotel/the-ledder-house-5.html',
#  'https://www.booking.com/reviews/us/hotel/234-newbury.html',
#  'https://www.booking.com/reviews/us/hotel/beautiful-bunker-hill-2-bd.html',
#  'https://www.booking.com/reviews/us/hotel/boston.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-apartment-on-arch-street-1b.html',
#  'https://www.booking.com/reviews/us/hotel/102-chandler-7-by-lyon-apartments-boston12.html',
#  'https://www.booking.com/reviews/us/hotel/102-chandler-5-by-lyon-apartments.html',
#  'https://www.booking.com/reviews/us/hotel/102-chandler-8-by-lyon-apartments.html',
#  'https://www.booking.com/reviews/us/hotel/102-chandler-6-by-lyon-apartments.html',
#  'https://www.booking.com/reviews/us/hotel/three-bedroom-on-south-street-apt-3.html',
#  'https://www.booking.com/reviews/us/hotel/one-bedroom-on-chestnut-hill-avenue-apt-9.html',
#  'https://www.booking.com/reviews/us/hotel/north-end-enchanted-cottage.html']

# %%
# get all reviews for each hotel with a valid review page
def get_all_reviews_for_each_hotel(html):
    soup = BeautifulSoup(html, "html5lib")
    temp = soup.find('h1', {'class' :'item hotel_name'})
    parsestring = str(temp).split('>')
    hotel_name = parsestring[2].split('<')[0].strip()
    try:
        review_boxes = soup.findAll('li', {'class' :'review_item clearfix '})
    # if hotel doesn't have a review page then url is not valid, return
    except Exception as e:
        return
    for review_box in review_boxes:
        try:
            h4 = review_box.find('h4')
            parsestring = str(h4).split('>')
            reviewer_name = parsestring[2].split('<')[0].strip()
        except Exception as e:
            reviewer_name = 'N/A'
        try:
            country = review_box.find('span', {'class' :'reviewer_country'})
            parsestring = str(country).split('>')
            ethnicity = parsestring[5].split('<')[0].strip()
        except Exception as e:
            ethnicity = 'N/A'
        try:    
            num_reviews = review_box.find('div', {'class' :'review_item_user_review_count'}).find(text=True).strip()
        except Exception as e:
            num_reviews = 'N/A'
        try: 
            date = review_box.find('p', {'class' :'review_item_date'}).find(text=True).strip()
            date = date.replace(',', ' ')
        except Exception as e:
            date = 'N/A'
        try:
            rating = review_box.find('span', {'class' :'review-score-badge'}).find(text=True).strip()
        except Exception as e:
            rating = 'N/A'
        try:
            neg = review_box.find('p', {'class' :'review_neg'})
            parsestring = str(neg).split('>')
            neg_review = parsestring[4].split('<')[0].strip()
            neg_review = neg_review.replace(',', '.')
        except Exception as e:
            neg_review = 'N/A'
        while neg_review.find('\n') != -1:
            i = neg_review.index('\n')
            neg_review = neg_review[0:i] + neg_review[i+1:]
        try:   
            pos = review_box.find('p', {'class' :'review_pos'})
            parsestring = str(pos).split('>')
            pos_review = parsestring[4].split('<')[0].strip()
            pos_review = pos_review.replace(',', '.')
        except Exception as e:
            pos_review = 'N/A'
        while pos_review.find('\n') != -1:
            i = pos_review.index('\n')
            pos_review = pos_review[0:i] + pos_review[i+1:]
        print(hotel_name + ',' + reviewer_name + ',' + ethnicity + ',' + num_reviews + ',' + date + ',' + rating + ',' + neg_review + ',' + pos_review, file = outfile)
    
    # Get next URL page if exists, else exit
    try:
        next_page = review_box.find('p', {'class' :'page_link review_next_page'})
        parsestring = str(next_page).split('>')
        temp = parsestring[1]
        if len(temp) < 4:
            return
        quotes = [m.start() for m in re.finditer('"', temp)]
        next_url = temp[quotes[0]+1:quotes[1]]
        next_url = 'https://www.booking.com' + next_url
        response = requests.get(next_url)
        html = response.text.encode('utf-8')
        return get_all_urls(html)
    except Exception as e:
        return

# %%
# get all reviews for all hotels with valid review pages
def get_all_reviews(urls):
    for url in urls:
        response = requests.get(url)
        html = response.text.encode('utf-8')
        get_all_reviews_for_each_hotel(html)
    return

# %%
start = time.time()
outfile = open('review_ratings.csv', 'w')
print('hotel_name,reviewer_name,ethnicity,num_reviews,date,rating,neg_review,pos_review', file = outfile)
get_all_reviews(review_urls)
outfile.close()
end = time.time()
print(end - start)
# Out:
# 1266.1616411209106

# %% [markdown]
# It took us about 2.3 minutes to produce traveler_ratings.csv and 21 minutes to produce review_ratings.csv.
